# %% [markdown]
# <a href="https://colab.research.google.com/github/Isaiah-Essien/Calculus_assignment/blob/main/Group8_Quiz_2___Calculus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: Write a dynamic function to find the derivative of any function f(x)

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp

# %%
x = sp.symbols('x')# definig the symbol x globally

# %%
#Function that returns the derivative of a polynomial using sympy
def calculate_derivative(equation):
    function = sp.sympify(equation)
    derivative = sp.diff(function, x)
    return derivative

# %% [markdown]
# # Task 2: Test the derivative function written with a quadratic equation of your choice
# *NB: Must have atleast 2 minimas and atleast 2 maximas*

# %%
polynomial = x**5-16*x**3+10*x
derivative = calculate_derivative(polynomial)
print(f"The derivative of {polynomial} is: {derivative}")
# Out:
# The derivative of x**5 - 16*x**3 + 10*x is: 5*x**4 - 48*x**2 + 10

# %% [markdown]
# #Task 3: Plot a graph of the Equation must have 4 points of inflection

# %%
# Define the polynomial function
def polynomial(x):
    return x**5-16*x**3+10*x

# Generate x values
x = np.linspace(-4, 4, 500)  # Adjust the range as needed

# Calculate y values
y = polynomial(x)

# Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='x**5-16*x**3+10*x', color='brown')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph of the Polynomial x**5-16*x**3+10*x')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Task 4: Create separate array of Minimas and maximas

# %%
x = sp.symbols('x')
# Define the polynomial function
polynomial = x**5-16*x**3+10*x

# Compute the first derivative
first_derivative = sp.diff(polynomial, x)

# Find critical points and convertin the points to floats
arr_critical_points=[]
critical_points = sp.solve(first_derivative, x)
for cp in critical_points:
  arr_critical_points.append(float(cp))

# Compute the second derivative
second_derivative = sp.diff(first_derivative, x)

# Classify critical points into maxima and minima arrays
arr_maximas = []
arr_minimas = []
for point in critical_points:
    # Evaluate the second derivative at the critical point
    second_derivative_at_point = second_derivative.subs(x, point)
    if second_derivative_at_point > 0:
        arr_minimas.append(float(point))
    elif second_derivative_at_point < 0:
        arr_maximas.append(float(point))

# Output the results
print("Polynomial:", polynomial)
print("First Derivative:", first_derivative)
print("Second Derivative:", second_derivative)
print("Critical Points:", arr_critical_points)

print(f'the array of minimas is {arr_minimas} and the array of maximas is {arr_maximas}')
# Out:
# Polynomial: x**5 - 16*x**3 + 10*x
# First Derivative: 5*x**4 - 48*x**2 + 10
# Second Derivative: 20*x**3 - 96*x
# Critical Points: [-0.4615864204329608, 0.4615864204329608, -3.06381102166434, 3.06381102166434]
# the array of minimas is [-0.4615864204329608, 3.06381102166434] and the array of maximas is [0.4615864204329608, -3.06381102166434]

# %% [markdown]
# ## **Task 5:** Compute Global Minima and Maxima

# %%
# Find the global maximum and minimum
global_maximum = max(arr_critical_points, key=lambda p: polynomial.subs(x, p))
global_minimum = min(arr_critical_points, key=lambda p: polynomial.subs(x, p))

# Print the critical points and global extrema
print("Critical Points:", arr_critical_points)
print("Global Maximum:", global_maximum)
print("Global Minimum:", global_minimum)
# Out:
# Critical Points: [-0.4615864204329608, 0.4615864204329608, -3.06381102166434, 3.06381102166434]
# Global Maximum: -3.06381102166434
# Global Minimum: 3.06381102166434

# %% [markdown]
# # **Task 6:** Visualize the Global Minima and Maxima:

# %%
# Generate x values for plotting
x_vals = np.linspace(-4, 4, 500)

# Generate y values for the polynomial
y_vals = [polynomial.subs(x, val) for val in x_vals]

# Plot the polynomial
plt.figure(figsize=(10, 6))
plt.plot(x_vals, y_vals, label='x**5 - 16*x**3 + 10*x', color='brown')

# getting the local maxima and mina values
local_maximum = min(arr_maximas, key=lambda p: polynomial.subs(x, p))
local_minimum = max(arr_minimas, key=lambda p: polynomial.subs(x, p))

# Highlight the global maxima and minima
plt.scatter(arr_maximas, [polynomial.subs(x, val) for val in arr_maximas], color='green', label=f'local Maxima: {local_maximum:.4f}')
plt.scatter(arr_minimas, [polynomial.subs(x, val) for val in arr_minimas], color='red', label=f'local Minima: {local_minimum:.4f}')
plt.scatter([global_maximum], [polynomial.subs(x, global_maximum)], color='purple', label=f'Global Maximum: {global_maximum:.4f}')
plt.scatter([global_minimum], [polynomial.subs(x, global_minimum)], color='blue', label=f'Global Minimum: {global_minimum:.4f}')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph of the Polynomial x**5 - 16*x**3 + 10*x with Extrema')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# #Finally, What is the global Minima and the Global maxima _ Plot this so that I can see

# %% [markdown]
# # **Challenges faced and how they were solved**

# %% [markdown]
# **For this assignment, we faced a number programming challenges listed below:**
#
#
# 1.   **Finding a polynomial with 2 minimas and maxima:** To solve this challenge, we had to work backwards using the roots of the polynomial. We used factor theorem to solve for the equation of the polynomial with n>3, where n is the power of the first x
#
#
# 2.  **Using SymPy liabrary effectively to check for Minima and Maxima**: this was probably the hardest part of our task. To have a polynomial of 2 maxima and 2 minima is evidently hard. First, we have to find the critical points, loop through this points to find the maxima and minima. This point uses the comparison operator in symPy. Sympy here does not allow comparison of complex variables( such as variables with squareroots), so it would throw errors such as type error, while checking if the second derivative of our said polynomial is > 0.
#
# We decided to use the is_positive and is_megative methods, but they printed  empty arrays for maxima and minima beacuse our polynomial had no negative critical point. We discovered that a polynomial with 2 mainimas and a maxima was easier to compute programatically. We opted into that after getting approval from the specialization coach.
# Fortunatly, in our pursuit of polynomials, we found an apt equation that has two maximas and minimas.

# %% [markdown]
# # **Helpful resources**

# %% [markdown]
# **Below are some of the resources we found helpful while doing this assignment:**
#
# 1.   [Python discussion forum](https://discuss.python.org/t/plot-a-polynomial/8945/2)
# 2.   [CueMath_ Inflection points](https://www.cuemath.com/calculus/maxima-and-minima/)
# 3. [First derivatives](https://www.geeksforgeeks.org/first-derivative-test/)

# %% [markdown]
# # Things trhat may help
#
# We came up with a functon
#
# $$
# f(x) = 4x^2 + x^-1
# $$
#
# So we create a fucntion in python
#
#
#
# ```
# def f(x):
#   #see our code below
# ```

# %%
#This is an Example of a quadratic function
def f(x):
   return (4 * (x** 2)) + (x ** -1)

# %% [markdown]
# We manuall calculated the derivative  and got that
# $$
# df(x)/dx = 8x^1 + x^-2
# $$
#
# Using the formula above we find points where the derivative is 0
#
# the values are:
#
# $$
# x1 = 0.5, x1 = - 0.5,x1 = 0,
# $$
#
# If you replace this in our original formula
#
# $$
# f(0.5) = 4(0.5)^2 + (0.5^-1 = -1.0
# $$
# $$
# f(0) = 4x^2 + x^-1 = No solution
# $$
# $$
# f(-0.5) = 4x^2 + x^-1 = 1
# $$
#
# Meaning our curve is flat at point $$(0.5,1) $$ and at $$ (-0.5,1)$$
#
# Proof Pending........
#
# Here is how we tried with code and got some errors

# %%
x1 = 0.5
x2 = -0.5
x3 = 0

y1 = f(x1)
y2 = f(x2)
y3 = f(x3)

print(y2)
(0.5,3)

# %% [markdown]
# # **You can now do the Rest.All the Best ........**

# %% [markdown]
# **This assignment is the most ambigous assignment i've ever had in ALU**
